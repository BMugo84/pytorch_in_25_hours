# %%
#Import the libraries to use
import geopandas as gdp
import folium
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
pd.set_option('max_colwidth', None)
pd.options.display.max_rows = 300
pd.describe_option('max_colwidth')
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: None]

# %%
# investigate data in the geospacial file using geopandas 
constituencies_json = gdp.read_file('_Kenya+Constituencies_kenya_constituencies.geojson')
constituencies_json

# %%
# display only the constituencies column

constituencies_json['CONSTITUEN']
# Out:
# 0                KAMUKUNJI
# 1                WESTLANDS
# 2          DAGORETTI NORTH
# 3                 ROYSAMBU
# 4                  STAREHE
# 5                  LANGATA
# 6          DAGORETTI SOUTH
# 7                 KASARANI
# 8                  RUARAKA
# 9                    KIBRA
# 10                 MATHARE
# 11                 KISAUNI
# 12                   MVITA
# 13                   JOMVU
# 14                   NYALI
# 15                  LIKONI
# 16                 KINANGO
# 17                  MATUGA
# 18             LUNGA LUNGA
# 19               MSAMBWENI
# 20                KALOLENI
# 21                   GANZE
# 22            KILIFI NORTH
# 23            KILIFI SOUTH
# 24                MAGARINI
# 25                   RABAI
# 26                 MALINDI
# 27                  GALOLE
# 28                    BURA
# 29                  GARSEN
# 30               LAMU WEST
# 31               LAMU EAST
# 32                WUNDANYI
# 33                     VOI
# 34                 MWATATE
# 35                  TAVETA
# 36               BALAMBALA
# 37                   IJARA
# 38                  DADAAB
# 39        GARISSA TOWNSHIP
# 40                    FAFI
# 41                 LAGDERA
# 42              WAJIR WEST
# 43             WAJIR NORTH
# 44             WAJIR SOUTH
# 45                  TARBAJ
# 46                   ELDAS
# 47              WAJIR EAST
# 48           MANDERA SOUTH
# 49           MANDERA NORTH
# 50            MANDERA WEST
# 51                 BANISSA
# 52              NORTH HORR
# 53                  MOYALE
# 54                LAISAMIS
# 55                    SAKU
# 56            ISIOLO NORTH
# 57            ISIOLO SOUTH
# 58            NORTH IMENTI
# 59            TIGANIA WEST
# 60            SOUTH IMENTI
# 61                   BUURI
# 62            IGEMBE SOUTH
# 63          IGEMBE CENTRAL
# 64            TIGANIA EAST
# 65          CENTRAL IMENTI
# 66            IGEMBE NORTH
# 67                   MAARA
# 68                 THARAKA
# 69     CHUKA/IGAMBANG'OMBE
# 70               RUNYENJES
# 71            MBEERE NORTH
# 72                MANYATTA
# 73            MBEERE SOUTH
# 74              KITUI EAST
# 75              KITUI WEST
# 76             KITUI RURAL
# 77             KITUI SOUTH
# 78           KITUI CENTRAL
# 79                   YATTA
# 80           MACHAKOS TOWN
# 81               MATUNGULU
# 82                   MWALA
# 83                 MASINGA
# 84                KANGUNDO
# 85                  MAVOKO
# 86                KATHIANI
# 87                KIPIPIRI
# 88                KINANGOP
# 89                NDARAGWA
# 90                   KIENI
# 91                 MATHIRA
# 92                  OTHAYA
# 93                    TETU
# 94              MUKURWEINI
# 95              NYERI TOWN
# 96                 GICHUGU
# 97       KIRINYAGA CENTRAL
# 98                    NDIA
# 99                    MWEA
# 100               MATHIOYA
# 101                KANDARA
# 102                MARAGWA
# 103                KANGEMA
# 104                 KIGUMO
# 105                 KIHARU
# 106          GATUNDU NORTH
# 107                 KABETE
# 108                KIAMBAA
# 109             GITHUNGURI
# 110             THIKA TOWN
# 111                GATANGA
# 112                 KIKUYU
# 113                 LIMURU
# 114          GATUNDU SOUTH
# 115                   LARI
# 116                   JUJA
# 117                  RUIRU
# 118                 KIAMBU
# 119          TURKANA NORTH
# 120           TURKANA EAST
# 121        TURKANA CENTRAL
# 122           TURKANA WEST
# 123                  LOIMA
# 124          TURKANA SOUTH
# 125             KAPENGURIA
# 126                  SIGOR
# 127              KACHELIBA
# 128            POKOT SOUTH
# 129          MARAKWET WEST
# 130          SAMBURU NORTH
# 131           SAMBURU WEST
# 132           SAMBURU EAST
# 133               AINABKOI
# 134                 MOIBEN
# 135                    SOY
# 136                  TURBO
# 137                 KESSES
# 138               KAPSERET
# 139          MARAKWET EAST
# 140            KEIYO NORTH
# 141            KEIYO SOUTH
# 142                  MOSOP
# 143            NANDI HILLS
# 144                 EMGWEN
# 145               TINDERET
# 146                  ALDAI
# 147               CHESUMEI
# 148        BARINGO CENTRAL
# 149          BARINGO NORTH
# 150                MOGOTIO
# 151          ELDAMA RAVINE
# 152          BARINGO SOUTH
# 153                  TIATY
# 154         LAIKIPIA NORTH
# 155                SUBUKIA
# 156          KURESOI SOUTH
# 157                  NJORO
# 158       NAKURU TOWN EAST
# 159                 RONGAI
# 160               NAIVASHA
# 161                 GILGIL
# 162       NAKURU TOWN WEST
# 163          KURESOI NORTH
# 164                   MOLO
# 165                 BAHATI
# 166            NAROK SOUTH
# 167            NAROK NORTH
# 168               KILGORIS
# 169             NAROK WEST
# 170          EMURUA DIKIRR
# 171             NAROK EAST
# 172        KAJIADO CENTRAL
# 173           KAJIADO WEST
# 174           KAJIADO EAST
# 175          KAJIADO SOUTH
# 176          KAJIADO NORTH
# 177           KIBWEZI WEST
# 178                 MBOONI
# 179                MAKUENI
# 180                  KAITI
# 181                 KILOME
# 182           KIBWEZI EAST
# 183                 BELGUT
# 184         KIPKELION WEST
# 185           SIGOWET/SOIN
# 186         KIPKELION EAST
# 187                AINAMOI
# 188                 KONOIN
# 189               SHINYALU
# 190                MATUNGU
# 191                 BUTERE
# 192               KHWISERO
# 193                 MALAVA
# 194              IKOLOMANI
# 195                LURAMBI
# 196            MUMIAS WEST
# 197              NAVAKHOLO
# 198            MUMIAS EAST
# 199                 HAMISI
# 200                SABATIA
# 201                 LUANDA
# 202                 VIHIGA
# 203                EMUHAYA
# 204                KANDUYI
# 205              MT. ELGON
# 206               KIMILILI
# 207                SIRISIA
# 208                 BUMULA
# 209               TONGAREN
# 210            WEBUYE EAST
# 211               KABUCHAI
# 212            WEBUTE WEST
# 213             TESO NORTH
# 214                 BUTULA
# 215                FUNYULA
# 216             TESO SOUTH
# 217                MATAYOS
# 218                NAMBALE
# 219              BUDALANGI
# 220                 UGENYA
# 221                RARIEDA
# 222                  BONDO
# 223                 UGUNJA
# 224                    GEM
# 225           ALEGO USONGA
# 226                 RANGWE
# 227                KASIPUL
# 228                   SUBA
# 229            KARACHUONYO
# 230        KABONDO KASIPUL
# 231                  MBITA
# 232                 NDHIWA
# 233          HOMA BAY TOWN
# 234             KURIA EAST
# 235                NYATIKE
# 236                 AWENDO
# 237             KURIA WEST
# 238                  URIRI
# 239                  RONGO
# 240       NYARIBARI CHACHE
# 241    KITUTU CHACHE NORTH
# 242       NYARIBARI MASABA
# 243       BOMACHOGE CHACHE
# 244                 BOBASI
# 245       BOMACHOGE BORABU
# 246               BONCHARI
# 247    KITUTU CHACHE SOUTH
# 248        SOUTH MUGIRANGO
# 249                 BURETI
# 250             CHEPALUNGU
# 251             BOMET EAST
# 252                  SOTIK
# 253          BOMET CENTRAL
# 254        NORTH MUGIRANGO
# 255         WEST MUGIRANGO
# 256          KITUTU MASABA
# 257                 BORABU
# 258                NYAKACH
# 259                   SEME
# 260                 NYANDO
# 261            KISUMU WEST
# 262            KISUMU EAST
# 263               MUHORONI
# 264         KISUMU CENTRAL
# 265                 LUGARI
# 266               ENDEBESS
# 267                 KWANZA
# 268                 SABOTI
# 269             CHERANGANY
# 270               KIMININI
# 271               LIKUYANI
# 272                  LAFEY
# 273           MANDERA EAST
# 274          EMBAKASI WEST
# 275          EMBAKASI EAST
# 276         EMBAKASI NORTH
# 277       EMBAKASI CENTRAL
# 278         EMBAKASI SOUTH
# 279               MAKADARA
# 280            MWINGI WEST
# 281         MWINGI CENTRAL
# 282           MWINGI NORTH
# 283               OL JOROK
# 284               OL KALOU
# 285              SUNA EAST
# 286              SUNA WEST
# 287          LAIKIPIA WEST
# 288          LAIKIPIA EAST
# 289              CHANGAMWE
# 290                   None
# 291                   None
# 292                   None
# 293                   None
# 294                   None
# Name: CONSTITUEN, dtype: object
